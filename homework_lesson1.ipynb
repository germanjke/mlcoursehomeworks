# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/Gera/Desktop/something else/datasets/data/titanic_train.csv' , index_col='PassengerId')

# %%
data[(data['Embarked'] == 'C') & (data.Fare > 200)].head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 119                 0       1
# 259                 1       1
# 300                 1       1
# 312                 1       1
# 378                 0       1
#
#                                                         Name     Sex   Age  \
# PassengerId
# 119                                 Baxter, Mr. Quigg Edmond    male  24.0
# 259                                         Ward, Miss. Anna  female  35.0
# 300          Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 312                               Ryerson, Miss. Emily Borie  female  18.0
# 378                                Widener, Mr. Harry Elkins    male  27.0
#
#              SibSp  Parch    Ticket      Fare            Cabin Embarked
# PassengerId
# 119              0      1  PC 17558  247.5208          B58 B60        C
# 259              0      0  PC 17755  512.3292              NaN        C
# ...

# %%
def age_category(age):
    if age < 30:
        return 1
    elif age < 55:
        return 2
    else:
        return 3

# %%
age_categories = [age_category(age) for age in data.Age]

# %%
data['Age_category'] = age_categories

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...

# %%
data[(data['Sex'] == 'male')].shape
# Out:
# (577, 12)

# %%
data[(data['Sex'] == 'female')].shape
# Out:
# (314, 12)

# %%
data.shape
# Out:
# (891, 12)

# %%
577 + 314
# Out:
# 891

# %%
data[(data['Sex'] == 'male') & (data['Pclass'] == 2)].head()
# Out:
#              Survived  Pclass                          Name   Sex   Age  \
# PassengerId
# 18                  1       2  Williams, Mr. Charles Eugene  male   NaN
# 21                  0       2          Fynney, Mr. Joseph J  male  35.0
# 22                  1       2         Beesley, Mr. Lawrence  male  34.0
# 34                  0       2         Wheadon, Mr. Edward H  male  66.0
# 71                  0       2    Jenkin, Mr. Stephen Curnow  male  32.0
#
#              SibSp  Parch      Ticket  Fare Cabin Embarked  Age_category
# PassengerId
# 18               0      0      244373  13.0   NaN        S             3
# 21               0      0      239865  26.0   NaN        S             2
# 22               0      0      248698  13.0   D56        S             2
# 34               0      0  C.A. 24579  10.5   NaN        S             3
# 71               0      0  C.A. 33111  10.5   NaN        S             2

# %%
pd.crosstab(data['Sex'] , data['Pclass'])
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        Age_category
# count    891.000000
# mean       1.814815
# std        0.801995
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        3.000000

# %%
data['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/Gera/Desktop/something else/datasets/data/titanic_train.csv' , index_col='PassengerId')

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
def age_category(age):
    if age < 30:
        return 1
    elif age > 60:
        return 2
    else:
        return 3

# %%
age_categories = [age_category(age) for age in data['Age']]

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data['AgeCat'] = age_categories

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  AgeCat
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S       1
# 2                1      0          PC 17599  71.2833   C85        C       3
# ...

# %%
pd.crosstab(data['AgeCat'] , data['Survived'])
# Out:
# Survived    0    1
# AgeCat
# 1         228  156
# 2          17    5
# 3         304  181

# %%
data['AgeCat'].count()
# Out:
# 891

# %%
data.AgeCat[(data['AgeCat'] == 2)].count()
# Out:
# 22

# %%
data.Survived[(data['Survived'] == 1)].count()
# Out:
# 342

# %%
data[(data['AgeCat'] == 2) & (data['Survived'] == 1)].count()
# Out:
# Survived    5
# Pclass      5
# Name        5
# Sex         5
# Age         5
# SibSp       5
# Parch       5
# Ticket      5
# Fare        5
# Cabin       3
# Embarked    4
# AgeCat      5
# dtype: int64

# %%
data.AgeCat[(data['AgeCat'] == 2) & (data['Survived'] == 1)].count()
# Out:
# 5

# %%
data.AgeCat[(data['AgeCat'] == 2) & (data['Survived'] == 1)]
# Out:
# PassengerId
# 276    2
# 484    2
# 571    2
# 631    2
# 830    2
# Name: AgeCat, dtype: int64

# %%
data.Age[(data['AgeCat'] == 2) & (data['Survived'] == 1)]
# Out:
# PassengerId
# 276    63.0
# 484    63.0
# 571    62.0
# 631    80.0
# 830    62.0
# Name: Age, dtype: float64

# %%
data.AgeCat[(data['AgeCat'] == 2) & (data['Survived'] == 1)].count() / data.AgeCat[(data['AgeCat'] == 2)].count()
# Out:
# 0.22727272727272727

# %%
data.AgeCat[(data['AgeCat'] == 1) & (data['Survived'] == 1)].count() / data.AgeCat[(data['AgeCat'] == 1)].count()
# Out:
# 0.40625

# %%
print ('Старые люди выживали чаще')
# Out:
# Старые люди выживали чаще

# %%
data.Survived[(data['Sex'] == 'male') & (data['Survived'] == 1)].count() / data.Survived[(data['Sex'] == 'male')].count()
# Out:
# 0.18890814558058924

# %%
data.Survived[(data['Sex'] == 'female') & (data['Survived'] == 1)].count() / data.Survived[(data['Sex'] == 'female')].count()
# Out:
# 0.7420382165605095

# %%
print ('18.9% среди мужчин и 74.2% среди женщин')
# Out:
# 18.9% среди мужчин и 74.2% среди женщин

# %%
data['Name'].value_counts()
# Out:
# Carter, Mrs. William Ernest (Lucile Polk)          1
# Staneff, Mr. Ivan                                  1
# Panula, Mrs. Juha (Maria Emilia Ojala)             1
# Coutts, Master. Eden Leslie "Neville"              1
# Olsson, Miss. Elina                                1
# Perreault, Miss. Anne                              1
# Andrews, Mr. Thomas Jr                             1
# Morrow, Mr. Thomas Rowan                           1
# Rice, Master. Eugene                               1
# Hawksford, Mr. Walter James                        1
# Lahtinen, Mrs. William (Anna Sylfven)              1
# Moss, Mr. Albert Johan                             1
# Collyer, Mrs. Harvey (Charlotte Annie Tate)        1
# Culumovic, Mr. Jeso                                1
# Meo, Mr. Alfonzo                                   1
# Cameron, Miss. Clear Annie                         1
# Herman, Mrs. Samuel (Jane Laver)                   1
# Pettersson, Miss. Ellen Natalia                    1
# ...

# %%
data['Name'][(data.Sex == 'male')].apply(lambda s: s.strip().split()).values
# Out:
# array([list(['Braund,', 'Mr.', 'Owen', 'Harris']),
#        list(['Allen,', 'Mr.', 'William', 'Henry']),
#        list(['Moran,', 'Mr.', 'James']),
#        list(['McCarthy,', 'Mr.', 'Timothy', 'J']),
#        list(['Palsson,', 'Master.', 'Gosta', 'Leonard']),
#        list(['Saundercock,', 'Mr.', 'William', 'Henry']),
#        list(['Andersson,', 'Mr.', 'Anders', 'Johan']),
#        list(['Rice,', 'Master.', 'Eugene']),
#        list(['Williams,', 'Mr.', 'Charles', 'Eugene']),
#        list(['Fynney,', 'Mr.', 'Joseph', 'J']),
#        list(['Beesley,', 'Mr.', 'Lawrence']),
#        list(['Sloper,', 'Mr.', 'William', 'Thompson']),
#        list(['Emir,', 'Mr.', 'Farred', 'Chehab']),
#        list(['Fortune,', 'Mr.', 'Charles', 'Alexander']),
#        list(['Todoroff,', 'Mr.', 'Lalio']),
#        list(['Uruchurtu,', 'Don.', 'Manuel', 'E']),
#        list(['Wheadon,', 'Mr.', 'Edward', 'H']),
#        list(['Meyer,', 'Mr.', 'Edgar', 'Joseph']),
# ...

# %%
all_men_names = np.concatenate(data['Name'][(data.Sex == 'male')].apply(lambda s: s.strip().split()).values)

# %%
len(all_men_names)
# Out:
# 2160

# %%
all_men_names
# Out:
# array(['Braund,', 'Mr.', 'Owen', ..., 'Dooley,', 'Mr.', 'Patrick'],
#       dtype='<U23')

# %%
pd.Series(list(all_men_names)).value_counts()
# Out:
# Mr.                517
# William             47
# Master.             40
# John                36
# Henry               28
# George              20
# James               20
# Charles             19
# Thomas              15
# Edward              14
# Johan               13
# Richard             12
# Alfred              11
# Arthur              11
# Joseph              10
# Frederick           10
# Samuel               9
# Jr                   9
# Robert               8
# Peter                8
# Karl                 8
# Victor               7
# J                    7
# Leonard              7
# Ernest               7
# Martin               7
# Alexander            6
# H                    6
# Dr.                  6
# Rev.                 6
#                   ...
# Herbert              1
# Billiard,            1
# Andrews,             1
# Josef                1
# Kent,                1
# Greenberg,           1
# Beane,               1
# Watson,              1
# Celotti,             1
# ...

# %%
print ('Самое популярное мужское имя на корабле - Williams')
# Out:
# Самое популярное мужское имя на корабле - Williams

# %%
import warnings
warnings.simplefilter('ignore')
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data['Fare'].hist()

# %%
pd.scatter_matrix(data[['Fare' , 'Age' , 'Survived']],
                  figsize=(15, 15), diagonal='kde')
plt.show()

# %%
data.boxplot(column = 'Age' , by = 'Survived')
plt.show()

# %%
print ("Средний возраст выживших - выше, чем средний возраст погибших")
# Out:
# Средний возраст выживших - выше, чем средний возраст погибших

# %%
data.boxplot(column = 'Age' , by = ['Sex' , 'Pclass'])
plt.show()

# %%
print ("Исходя из данного боксплота можно выбрать следующие верные утверждения : \n Мужчины всех классов в среднем старше женщин того же класса \n В среднем люди в 1 классе старше, чем во 2-ом, а те старше представителей 3-го класса")
# Out:
# Исходя из данного боксплота можно выбрать следующие верные утверждения :
#  Мужчины всех классов в среднем старше женщин того же класса
#  В среднем люди в 1 классе старше, чем во 2-ом, а те старше представителей 3-го класса
